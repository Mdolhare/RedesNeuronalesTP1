# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import mnist

# %%
(x_trainp, y_train) , (x_test, y_test) = mnist.load_data()
train_morpho = pd.read_csv("Data/train-morpho.csv")
test_morpho = pd.read_csv("Data/t10k-morpho.csv")

# %%
train_morpho
# Out:
#        index      area     length  thickness     slant      width     height
# 0          0  107.3125  50.266504   2.460658  0.231074  14.539572  19.849054
# 1          1  123.2500  51.198485   2.616601  0.331858  15.387810  19.341053
# 2          2   78.3750  45.927670   1.891592 -0.212196  20.479656  19.114880
# 3          3   67.3125  22.849242   2.919769  0.509185   5.358179  19.724599
# 4          4   91.1875  46.284271   2.247425  0.007590  13.275437  19.527523
# ...      ...       ...        ...        ...       ...        ...        ...
# 59995  59995  102.1875  61.415999   1.941380  0.366472  11.840672  19.937599
# 59996  59996  108.5625  46.705844   2.538071  0.364359  13.325950  19.688557
# 59997  59997   87.0625  44.523864   2.058077  0.257784  14.133500  20.070647
# 59998  59998   82.2500  53.337572   1.667193  0.310377  15.251961  19.692976
# 59999  59999   84.7500  56.966252   1.759232  0.588772  13.415460  17.869924
#
# [60000 rows x 7 columns]

# %%
slant = train_morpho['slant'].to_numpy()
slant
# Out:
# array([ 0.23107447,  0.33185821, -0.21219623, ...,  0.25778359,
#         0.31037662,  0.58877155])

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, s_train, s_val = train_test_split(x_trainp, slant, test_size=0.25, random_state=42)
saltear, saltear2, y_train, y_val = train_test_split(x_trainp, y_train, test_size=0.25, random_state=42)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout, Embedding, Concatenate, Input
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(784/2, activation='relu'))
model.add(Dense(784/4, activation='relu'))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 392)               307720
#
#  dense_4 (Dense)             (None, 196)               77028
#
#  dense_5 (Dense)             (None, 1)                 197
#
# =================================================================
# Total params: 384,945
# Trainable params: 384,945
# Non-trainable params: 0
# _________________________________________________________________

# %%
stp = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

model.compile(loss='MAE', optimizer=Adam(learning_rate=0.001))
history = model.fit(x = x_train, y = s_train, validation_data = (x_val, s_val), epochs=40, batch_size=32, callbacks=[stp])
# Out:
# Epoch 1/40
# 1407/1407 [==============================] - 12s 8ms/step - loss: 1.7163 - val_loss: 0.0880
# Epoch 2/40
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.1016 - val_loss: 0.1189
# Epoch 3/40
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.0613 - val_loss: 0.0412
# Epoch 4/40
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.0477 - val_loss: 0.0364
# Epoch 5/40
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.0437 - val_loss: 0.0353
# Epoch 6/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0374 - val_loss: 0.0319
# Epoch 7/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0336 - val_loss: 0.0413
# Epoch 8/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0314 - val_loss: 0.0295
# Epoch 9/40
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.0279 - val_loss: 0.0275
# Epoch 10/40
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.0267 - val_loss: 0.0307
# Epoch 11/40
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.0255 - val_loss: 0.0294
# Epoch 12/40
# 1407/1407 [==============================] - 10s 7ms/step - loss: 0.0235 - val_loss: 0.0224
# Epoch 13/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0229 - val_loss: 0.0220
# Epoch 14/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0220 - val_loss: 0.0214
# Epoch 15/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0221 - val_loss: 0.0255
# Epoch 16/40
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.0214 - val_loss: 0.0219
# Epoch 17/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0211 - val_loss: 0.0229
# Epoch 18/40
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.0202 - val_loss: 0.0210
# Epoch 19/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0202 - val_loss: 0.0204
# Epoch 20/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0199 - val_loss: 0.0253
# Epoch 21/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0203 - val_loss: 0.0202
# Epoch 22/40
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.0203 - val_loss: 0.0225
# Epoch 23/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0196 - val_loss: 0.0204
# Epoch 24/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0190 - val_loss: 0.0190
# Epoch 25/40
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.0185 - val_loss: 0.0224
# Epoch 26/40
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.0187 - val_loss: 0.0203
# Epoch 27/40
# 1407/1407 [==============================] - 11s 8ms/step - loss: 0.0183 - val_loss: 0.0214
# Epoch 28/40
# 1407/1407 [==============================] - 12s 8ms/step - loss: 0.0184 - val_loss: 0.0196

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, 0.25])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
y = model.predict(x_val)
# Out:
# 469/469 [==============================] - 1s 3ms/step

# %%
#for i in range(len(y)):
    #print(s_val[i], y[i])

# %%
input1 = Input(shape=(28, 28))

input2 = Input(shape=(1,))

first = Embedding(input_dim=10, output_dim=2, input_length=1)(input2)

flat1 = Flatten(input_shape=(1, 2))(first)

flat1 = Model(inputs=input2, outputs=flat1)

second = Flatten(input_shape=(28, 28))(input1)

second = Model(inputs=input1, outputs=second)

merged = Concatenate()([flat1.output, second.output])

act1 = Dense(786//2, activation='relu')(merged)

act2 = Dense(786//4, activation='relu')(act1)

output = Dense(1)(act2)

model2 = Model(inputs=[flat1.input, second.input], outputs=output)

model2.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 1)]          0           []
#
#  embedding_1 (Embedding)        (None, 1, 2)         20          ['input_4[0][0]']
#
#  input_3 (InputLayer)           [(None, 28, 28)]     0           []
#
#  flatten_2 (Flatten)            (None, 2)            0           ['embedding_1[0][0]']
#
#  flatten_3 (Flatten)            (None, 784)          0           ['input_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 786)          0           ['flatten_2[0][0]',
#                                                                   'flatten_3[0][0]']
#
#  dense_3 (Dense)                (None, 393)          309291      ['concatenate_1[0][0]']
#
#  dense_4 (Dense)                (None, 196)          77224       ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            197         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 386,732
# Trainable params: 386,732
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
stp = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

model2.compile(loss='MAE', optimizer=Adam(learning_rate=0.001))
history2 = model2.fit(x = [y_train, x_train], y = s_train, validation_data = ([y_val, x_val], s_val), epochs=40, batch_size=32, callbacks=[stp])
# Out:
# Epoch 1/40
# 1407/1407 [==============================] - 22s 14ms/step - loss: 1.5405 - val_loss: 0.2307
# Epoch 2/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.1054 - val_loss: 0.0655
# Epoch 3/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0647 - val_loss: 0.0477
# Epoch 4/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0546 - val_loss: 0.0496
# Epoch 5/40
# 1407/1407 [==============================] - 20s 15ms/step - loss: 0.0512 - val_loss: 0.0790
# Epoch 6/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0464 - val_loss: 0.0427
# Epoch 7/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0455 - val_loss: 0.0413
# Epoch 8/40
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0418 - val_loss: 0.0452
# Epoch 9/40
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0394 - val_loss: 0.0356
# Epoch 10/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0358 - val_loss: 0.0333
# Epoch 11/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0343 - val_loss: 0.0351
# Epoch 12/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0324 - val_loss: 0.0347
# Epoch 13/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0297 - val_loss: 0.0293
# Epoch 14/40
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.0288 - val_loss: 0.0266
# Epoch 15/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0272 - val_loss: 0.0282
# Epoch 16/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0264 - val_loss: 0.0300
# Epoch 17/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0260 - val_loss: 0.0295
# Epoch 18/40
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.0255 - val_loss: 0.0263
# Epoch 19/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0254 - val_loss: 0.0311
# Epoch 20/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0248 - val_loss: 0.0247
# Epoch 21/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0240 - val_loss: 0.0257
# Epoch 22/40
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.0235 - val_loss: 0.0237
# Epoch 23/40
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.0232 - val_loss: 0.0316
# Epoch 24/40
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.0233 - val_loss: 0.0251
# Epoch 25/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0228 - val_loss: 0.0222
# Epoch 26/40
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0225 - val_loss: 0.0239
# Epoch 27/40
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0231 - val_loss: 0.0227
# Epoch 28/40
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.0221 - val_loss: 0.0236
# Epoch 29/40
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0221 - val_loss: 0.0234

# %%
y2 = model2.predict([y_val, x_val])
# Out:
# 469/469 [==============================] - 1s 3ms/step

# %%
#for i in range(len(y2)):
    #print(s_val[i], y2[i])

# %%
plt.plot(history2.history['loss'], label='loss')
plt.plot(history2.history['val_loss'], label='val_loss')
plt.ylim([0, 0.25])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
emb = model2.get_weights()[0]
emb
# Out:
# array([[ 2.0574074 , -2.0615642 ],
#        [ 1.8155682 , -1.7574838 ],
#        [ 3.197487  , -3.3564944 ],
#        [ 1.8807156 , -1.8600314 ],
#        [ 4.3685923 , -4.4924498 ],
#        [ 5.1091375 , -5.0174193 ],
#        [ 1.9494665 , -1.937819  ],
#        [ 3.1515062 , -3.3325577 ],
#        [ 0.60909027, -0.5121473 ],
#        [ 1.0655328 , -1.1628801 ]], dtype=float32)

# %%
plt.scatter(emb[:, 0], emb[:, 1])
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(15, 3))

ax[0].scatter(train_morpho['slant'], train_morpho['area'], alpha=0.02)
ax[1].scatter(train_morpho['slant'], train_morpho['length'], alpha=0.02)
ax[2].scatter(train_morpho['slant'], train_morpho['thickness'], alpha=0.02)
ax[3].scatter(train_morpho['slant'], train_morpho['width'], alpha=0.02)
ax[4].scatter(train_morpho['slant'], train_morpho['height'], alpha=0.02)

fig.tight_layout()

plt.show()

# %%
p3input1 = Input(shape=(28, 28))

p3input2 = Input(shape=(1,))

p3relu2 = Dense(1, activation='relu')(p3input2)

p3relu2 = Model(inputs=p3input2, outputs=p3relu2)

p3second = Flatten(input_shape=(28, 28))(p3input1)

p3second = Model(inputs=p3input1, outputs=p3second)

p3merged = Concatenate()([p3relu2.output, p3second.output])

p3act1 = Dense(786/2, activation='relu')(p3merged)

p3act2 = Dense(786/4, activation='relu')(p3act1)

p3output = Dense(1)(p3act2)

model3 = Model(inputs=[p3relu2.input, p3second.input], outputs=p3output)

model3.summary()
# Out:
# Model: "model_49"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_67 (InputLayer)          [(None, 1)]          0           []
#
#  input_66 (InputLayer)          [(None, 28, 28)]     0           []
#
#  dense_68 (Dense)               (None, 1)            2           ['input_67[0][0]']
#
#  flatten_64 (Flatten)           (None, 784)          0           ['input_66[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 785)          0           ['dense_68[0][0]',
#                                                                   'flatten_64[0][0]']
#
#  dense_69 (Dense)               (None, 393)          308898      ['concatenate_40[0][0]']
#
#  dense_70 (Dense)               (None, 196)          77224       ['dense_69[0][0]']
#
#  dense_71 (Dense)               (None, 1)            197         ['dense_70[0][0]']
#
# ==================================================================================================
# Total params: 386,321
# Trainable params: 386,321
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
h = train_morpho['slant'].to_numpy()

saltear, saltear2, h_train, h_val = train_test_split(x_trainp, h, test_size=0.25, random_state=42)

# %%
stp = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

model3.compile(loss='MAE', optimizer=Adam(learning_rate=0.001))
history3 = model3.fit(x = [h_train, x_train], y = s_train, validation_data = ([h_val, x_val], s_val), epochs=40, batch_size=32, callbacks=[stp])
# Out:
# Epoch 1/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 1.7437 - val_loss: 0.1666
# Epoch 2/40
# 1407/1407 [==============================] - 12s 9ms/step - loss: 0.1338 - val_loss: 0.0999
# Epoch 3/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0815 - val_loss: 0.0830
# Epoch 4/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0647 - val_loss: 0.0568
# Epoch 5/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0591 - val_loss: 0.0579
# Epoch 6/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0555 - val_loss: 0.0491
# Epoch 7/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0595 - val_loss: 0.0496
# Epoch 8/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0607 - val_loss: 0.0567
# Epoch 9/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0597 - val_loss: 0.0638
# Epoch 10/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0595 - val_loss: 0.0485
# Epoch 11/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0562 - val_loss: 0.0727
# Epoch 12/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0582 - val_loss: 0.0574
# Epoch 13/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0549 - val_loss: 0.0586
# Epoch 14/40
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0512 - val_loss: 0.0496

# %%
y3 = model3.predict([h_val, x_val])
# Out:
# 469/469 [==============================] - 1s 3ms/step

# %%
plt.plot(history2.history['loss'], label='loss')
plt.plot(history2.history['val_loss'], label='val_loss')
plt.ylim([0, 0.25])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
